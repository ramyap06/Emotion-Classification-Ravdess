# %% [markdown]
# # Emotion classification using the RAVDESS dataset

# %% [markdown]
# The Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS) is licensed under CC BY-NA-SC 4.0. and can be downloaded free of charge at https://zenodo.org/record/1188976.
#
# ***Construction and Validation***
#
# Construction and validation of the RAVDESS is described in our paper: Livingstone SR, Russo FA (2018) The Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS): A dynamic, multimodal set of facial and vocal expressions in North American English. PLoS ONE 13(5): e0196391. https://doi.org/10.1371/journal.pone.0196391.
#
# The RAVDESS contains 7356 files. Each file was rated 10 times on emotional validity, intensity, and genuineness. Ratings were provided by 247 individuals who were characteristic of untrained adult research participants from North America. A further set of 72 participants provided test-retest data. High levels of emotional validity, interrater reliability, and test-retest intrarater reliability were reported. Validation data is open-access, and can be downloaded along with our paper from PLOS ONE.
#
# ***Description***
#
# The dataset contains the complete set of 7356 RAVDESS files (total size: 24.8 GB). Each of the 24 actors consists of three modality formats: Audio-only (16bit, 48kHz .wav), Audio-Video (720p H.264, AAC 48kHz, .mp4), and Video-only (no sound).  Note, there are no song files for Actor_18.
#
# ***Data***
#
# For this task, I have used 4948 samples from the RAVDESS dataset.
#
# The samples comes from:
#
# - Audio-only files;
# - Video + audio files: I have extracted the audio from each file using the script Mp4ToWav.py that you can find in the main directory of the project.
#
# ***License information***
#
# The RAVDESS is released under a Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License, CC BY-NA-SC 4.0
#
# ***File naming convention***
#
# Each of the 7356 RAVDESS files has a unique filename. The filename consists of a 7-part numerical identifier (e.g., 02-01-06-01-02-01-12.mp4). These identifiers define the stimulus characteristics:
#
# ***Filename identifiers***
#
# - Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
# - Vocal channel (01 = speech, 02 = song).
# - Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
# - Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the ‘neutral’ emotion.
# - Statement (01 = “Kids are talking by the door”, 02 = “Dogs are sitting by the door”).
# - Repetition (01 = 1st repetition, 02 = 2nd repetition).
# - Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# Filename example: 02-01-06-01-02-01-12.mp4
#
# - Video-only (02)
# - Speech (01)
# - Fearful (06)
# - Normal intensity (01)
# - Statement “dogs” (02)
# - 1st Repetition (01)
# - 12th Actor (12)
# - Female, as the actor ID number is even.

# %% [markdown]
# # Analysis
#
# We are using Colab, a Google Cloud environment for jupyter, so we need to import our files from Google Drive and then install LibROSA, a python package for music and audio analysis.
#
# After the import, we will plot the signal of the first file.

# %%
# !pip install librosa pandas tensorflow scikit-learn matplotlib
# Out:
# Requirement already satisfied: librosa in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.11.0)
# Requirement already satisfied: pandas in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.3)
# Requirement already satisfied: tensorflow in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.20.0)
# Requirement already satisfied: scikit-learn in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.7.2)
# Requirement already satisfied: matplotlib in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.3)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.64.0)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.16.3)
# Requirement already satisfied: joblib>=1.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (6.33.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from numba>=0.51.0->librosa) (0.46.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pooch>=1.1->librosa) (4.3.8)
# Requirement already satisfied: cffi>=1.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.23)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ramya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\ramya\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd
import glob
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
from tensorflow import keras
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Flatten, Dropout, Activation
from tensorflow.keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix

# %%
plt.figure(figsize=(12, 4))
librosa.display.waveshow(data, sr=sampling_rate)

# %%
data, sampling_rate = librosa.load('./data/Actor_01/03-01-01-01-01-01-01.wav')

# %%
plt.figure(figsize=(12, 4))
librosa.display.waveshow(data, sr=sampling_rate)

# %% [markdown]
# # Load all files
#
# We will create our numpy array extracting Mel-frequency cepstral coefficients (MFCCs), while the classes to predict will be extracted from the name of the file (see the introductory section of this notebook to see the naming convention of the files of this dataset).

# %%
path = './data/Actor_01'
lst = []

for subdir, dirs, files in os.walk(path):
  for file in files:
      try:
        #Load librosa array, obtain mfcss, store the file and the mcss information in a new array
        X, sample_rate = librosa.load(os.path.join(subdir, file))
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
        file = file[6:8]
        arr = mfccs, file
        lst.append(arr)
      # If the file is not valid, skip it
      except ValueError:
        continue

# %%
# Creating X and y: zip makes a list of all the first elements, and a list of all the second elements.
X, y = zip(*lst)

# %%
import numpy as np
X = np.asarray(X)
y = np.asarray(y)


X.shape, y.shape
# Out:
# ((60, 40), (60,))

# %% [markdown]
# # Decision Tree Classifier
#
# To make a first attempt in accomplishing this classification task I chose a decision tree:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

y_train = y_train.astype(int)
y_test = y_test.astype(int)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = dtree.predict(X_test)

# %% [markdown]
# Let's go with our classification report.
#
# Before we start, a quick reminder of the classes we are trying to predict:
#
# emotions = {
#     "neutral": "01",
#     "calm": "02",
#     "happy": "03",
#     "sad": "04",
#     "angry": "05",
#     "fearful": "06",
#     "disgust": "07",
#     "surprised": "08"
# }

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.67      1.00      0.80         2
#            2       1.00      0.75      0.86         4
#            3       1.00      0.33      0.50         3
#            4       0.00      0.00      0.00         0
#            5       0.67      1.00      0.80         2
#            6       0.67      1.00      0.80         2
#            7       0.75      0.75      0.75         4
#            8       1.00      0.33      0.50         3
#
#     accuracy                           0.70        20
#    macro avg       0.72      0.65      0.63        20
# weighted avg       0.85      0.70      0.71        20
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Random Forest

# %% [markdown]
# In this second approach, I switched to a random forest classifier and I made a gridsearch to make some hyperparameters tuning.
#
# The gridsearch is not shown in the code below otherwise the notebook will require too much time to run.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rforest = RandomForestClassifier(criterion="gini", max_depth=10, max_features="log2", 
                                 max_leaf_nodes = 100, min_samples_leaf = 3, min_samples_split = 20, 
                                 n_estimators= 22000, random_state= 5)

# %%
rforest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, max_features='log2', max_leaf_nodes=100,
#                        min_samples_leaf=3, min_samples_split=20,
#                        n_estimators=22000, random_state=5)

# %%
predictions = rforest.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         2
#            2       0.00      0.00      0.00         4
#            3       1.00      0.33      0.50         3
#            4       0.00      0.00      0.00         0
#            5       0.33      1.00      0.50         2
#            6       1.00      0.50      0.67         2
#            7       0.00      0.00      0.00         4
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.20        20
#    macro avg       0.29      0.23      0.21        20
# weighted avg       0.28      0.20      0.19        20
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # Neural network

# %% [markdown]
# Let's build our neural network!
#
# To do so, we need to expand the dimensions of our array, adding a third one using the numpy "expand_dims" feature.

# %%
x_traincnn = np.expand_dims(X_train, axis=2)
x_testcnn = np.expand_dims(X_test, axis=2)

# %%
x_traincnn.shape, x_testcnn.shape
# Out:
# ((40, 40, 1), (20, 40, 1))

# %%
model = Sequential()
model.add(Conv1D(128, 5,padding='same',
                 input_shape=(40,1)))
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(8)))
model.add(Conv1D(128, 5,padding='same',))
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(10))
model.add(Activation('softmax'))
opt = tf.keras.optimizers.RMSprop(learning_rate=0.00005, rho=0.9)
# Out:
# C:\Users\ramya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# With *model.summary* we can see a recap of what we have build:

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_12 (Conv1D)              │ (None, 40, 128)        │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 40, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 40, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_13 (Conv1D)              │ (None, 5, 128)         │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_19 (Activation)      │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 640)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 10)             │         6,410 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_20 (Activation)      │ (None, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 89,226 (348.54 KB)
#  Trainable params: 89,226 (348.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Now we can compile and fit our model:

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
print(x_traincnn.dtype, y_train.dtype)
# Out:
# float32 int32

# %%
cnnhistory=model.fit(x_traincnn, y_train, batch_size=16, epochs=1000, validation_data=(x_testcnn, y_test))
# Out:
# Epoch 1/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - accuracy: 0.1250 - loss: 20.3383 - val_accuracy: 0.1500 - val_loss: 10.3691
# Epoch 2/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1250 - loss: 14.7308 - val_accuracy: 0.1500 - val_loss: 7.3537
# Epoch 3/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1000 - loss: 12.9566 - val_accuracy: 0.1000 - val_loss: 5.7536
# Epoch 4/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1250 - loss: 10.9722 - val_accuracy: 0.1500 - val_loss: 5.2478
# Epoch 5/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.1500 - loss: 12.0638 - val_accuracy: 0.1500 - val_loss: 4.1987
# Epoch 6/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.0250 - loss: 9.9658 - val_accuracy: 0.0500 - val_loss: 3.9970
# Epoch 7/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1500 - loss: 7.3163 - val_accuracy: 0.0000e+00 - val_loss: 3.6586
# Epoch 8/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1500 - loss: 6.6336 - val_accuracy: 0.0000e+00 - val_loss: 3.2580
# Epoch 9/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1250 - loss: 7.1321 - val_accuracy: 0.2500 - val_loss: 2.7623
# Epoch 10/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1000 - loss: 7.5292 - val_accuracy: 0.1000 - val_loss: 2.8341
# Epoch 11/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.0500 - loss: 8.7250 - val_accuracy: 0.1500 - val_loss: 2.8230
# Epoch 12/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.1750 - loss: 6.6796 - val_accuracy: 0.2500 - val_loss: 2.4721
# Epoch 13/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.1500 - loss: 9.0304 - val_accuracy: 0.0000e+00 - val_loss: 2.6518
# Epoch 14/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.1250 - loss: 8.0896 - val_accuracy: 0.0000e+00 - val_loss: 4.0945
# Epoch 15/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.1750 - loss: 6.2403 - val_accuracy: 0.2500 - val_loss: 2.3859
# Epoch 16/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.0750 - loss: 8.6809 - val_accuracy: 0.0500 - val_loss: 2.5306
# Epoch 17/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1000 - loss: 7.8830 - val_accuracy: 0.3000 - val_loss: 2.4634
# Epoch 18/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.0750 - loss: 6.7385 - val_accuracy: 0.0500 - val_loss: 2.7799
# Epoch 19/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2000 - loss: 7.0391 - val_accuracy: 0.0500 - val_loss: 3.5084
# Epoch 20/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2000 - loss: 5.8400 - val_accuracy: 0.1000 - val_loss: 3.3662
# Epoch 21/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.
1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2250 - loss: 4.7523 - val_accuracy: 0.0500 - val_loss: 2.0450
# Epoch 119/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2000 - loss: 4.5240 - val_accuracy: 0.1500 - val_loss: 2.1251
# Epoch 120/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2250 - loss: 4.5377 - val_accuracy: 0.1000 - val_loss: 2.0883
# Epoch 121/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.1750 - loss: 5.2048 - val_accuracy: 0.1000 - val_loss: 2.1630
# Epoch 122/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1000 - loss: 5.4624 - val_accuracy: 0.1500 - val_loss: 2.0409
# Epoch 123/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2250 - loss: 4.9346 - val_accuracy: 0.1000 - val_loss: 2.5136
# Epoch 124/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1500 - loss: 5.3518 - val_accuracy: 0.0500 - val_loss: 2.5865
# Epoch 125/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2000 - loss: 4.9681 - val_accuracy: 0.0500 - val_loss: 2.7309
# Epoch 126/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2000 - loss: 5.1195 - val_accuracy: 0.1000 - val_loss: 2.3696
# Epoch 127/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2000 - loss: 3.8133 - val_accuracy: 0.0500 - val_loss: 2.9156
# Epoch 128/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1500 - loss: 5.0110 - val_accuracy: 0.0500 - val_loss: 2.6548
# Epoch 129/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3000 - loss: 4.9151 - val_accuracy: 0.1000 - val_loss: 2.6008
# Epoch 130/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3750 - loss: 4.4473 - val_accuracy: 0.2000 - val_loss: 1.9089
# Epoch 131/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2750 - loss: 3.6967 - val_accuracy: 0.2500 - val_loss: 2.0894
# Epoch 132/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3750 - loss: 3.6082 - val_accuracy: 0.3000 - val_loss: 2.2250
# Epoch 133/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.2750 - loss: 4.1307 - val_accuracy: 0.0500 - val_loss: 2.7699
# Epoch 134/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2250 - loss: 4.6933 - val_accuracy: 0.2500 - val_loss: 2.2300
# Epoch 135/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3500 - loss: 4.1089 - val_accuracy: 0.1000 - val_loss: 2.2313
# Epoch 136/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2500 - loss: 4.2240 - val_accuracy: 0.0500 - val_loss: 2.1801
# Epoch 137/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2500 - loss: 4.2484 - val_accuracy: 0.1500 - val_loss: 2.6619
# Epoch 138/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.2250 - loss: 4.0377 - val_accuracy: 0.1000 - val_loss: 2.1969
# Epoch 139/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2500 - loss: 4.7122 - val_accuracy: 0.3000 - val_loss: 2.1117
# Epoch 140/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1750 - loss: 4.7310 - val_accuracy: 0.0500 - val_loss: 2.6554
# Epoch 141/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2500 - loss: 2.9257 - val_accuracy: 0.1000 - val_loss: 2.6334
# Epoch 142/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3000 - loss: 3.6823 - val_accuracy: 0.0500 - val_loss: 2.9253
# Epoch 143/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2500 - loss: 3.8780 - val_accuracy: 0.1500 - val_loss: 2.1816
# Epoch 144/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.2000 - loss: 4.9921 - val_accuracy: 0.1500 - val_loss: 2.5598
# Epoch 145/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2750 - loss: 4.0855 - val_accuracy: 0.1500 - val_loss: 1.9188
# Epoch 146/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2250 - loss: 4.4899 - val_accuracy: 0.1000 - val_loss: 2.1306
# Epoch 147/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3000 - loss: 4.0999 - val_accuracy: 0.1000 - val_loss: 2.1358
# Epoch 148/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2250 - loss: 4.4212 - val_accuracy: 0.4000 - val_loss: 1.5081
# Epoch 149/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1750 - loss: 3.7940 - val_accuracy: 0.3000 - val_loss: 1.8142
# Epoch 150/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3500 - loss: 3.4747 - val_accuracy: 0.1000 - val_loss: 2.4029
# Epoch 151/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.1500 - loss: 4.8934 - val_accuracy: 0.0500 - val_loss: 2.8177
# Epoch 152/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2500 - loss: 4.2678 - val_accuracy: 0.3000 - val_loss: 2.2663
# Epoch 153/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3250 - loss: 4.6184 - val_accuracy: 0.2500 - val_loss: 2.2311
# Epoch 154/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3500 - loss: 3.4429 - val_accuracy: 0.3000 - val_loss: 2.1473
# Epoch 155/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.1500 - loss: 4.6964 - val_accuracy: 0.3000 - val_loss: 2.4321
# Epoch 156/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2750 - loss: 4.1696 - val_accuracy: 0.1500 - val_loss: 2.0640
# Epoch 157/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.2750 - loss: 3.5885 - val_accuracy: 0.0500 - val_loss: 3.3867
# Epoch 158/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2250 - loss: 4.4348 - val_accuracy: 0.3000 - val_loss: 2.0921
# Epoch 159/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2250 - loss: 4.0274 - val_accuracy: 0.2500 - val_loss: 2.6732
# Epoch 160/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2500 - loss: 3.8627 - val_accuracy: 0.2000 - val_loss: 2.8107
# Epoch 161/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2250 - loss: 4.3456 - val_accuracy: 0.3000 - val_loss: 2.3324
# Epoch 162/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3000 - loss: 4.3171 - val_accuracy: 0.3000 - val_loss: 1.9245
# Epoch 163/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2750 - loss: 3.5177 - val_accuracy: 0.3500 - val_loss: 1.6854
# Epoch 164/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3500 - loss: 4.0811 - val_accuracy: 0.4500 - val_loss: 1.7946
# Epoch 165/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4000 - loss: 3.7292 - val_accuracy: 0.3000 - val_loss: 1.7411
# Epoch 166/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1500 - loss: 4.0619 - val_accuracy: 0.2500 - val_loss: 2.1318
# Epoch 167/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2500 - loss: 3.5636 - val_accuracy: 0.3500 - val_loss: 1.8032
# Epoch 168/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2750 - loss: 4.0377 - val_accuracy: 0.2500 - val_loss: 1.8534
# Epoch 169/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3250 - loss: 2.9471 - val_accuracy: 0.2500 - val_loss: 2.2981
# Epoch 170/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4000 - loss: 3.0095 - val_accuracy: 0.4000 - val_loss: 1.9468
# Epoch 171/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.3000 - loss: 3.8429 - val_accuracy: 0.3000 - val_loss: 2.0433
# Epoch 172/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3000 - loss: 3.9888 - val_accuracy: 0.3000 - val_loss: 2.6138
# Epoch 173/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.1750 - loss: 3.9687 - val_accuracy: 0.2500 - val_loss: 2.5874
# Epoch 174/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3000 - loss: 2.7112 - val_accuracy: 0.3000 - val_loss: 2.2822
# Epoch 175/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.2500 - loss: 3.2022 - val_accuracy: 0.2500 - val_loss: 1.9612
# Epoch 176/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.2750 - loss: 3.1625 - val_accuracy: 0.2500 - val_loss: 2.0485
# Epoch 177/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3750 - loss: 3.1675 - val_accuracy: 0.2000 - val_loss: 1.8868
# Epoch 178/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4000 - loss: 2.8904 - val_accuracy: 0.3500 - val_loss: 1.6950
# Epoch 179/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2500 - loss: 3.4929 - val_accuracy: 0.3000 - val_loss: 1.6449
# Epoch 180/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2500 - loss: 4.0194 - val_accuracy: 0.4000 - val_loss: 1.5767
# Epoch 181/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.4000 - loss: 3.1901 - val_accuracy: 0.4000 - val_loss: 2.0630
# Epoch 182/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2500 - loss: 3.7045 - val_accuracy: 0.2500 - val_loss: 2.3851
# Epoch 183/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2750 - loss: 3.4838 - val_accuracy: 0.3000 - val_loss: 2.2150
# Epoch 184/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3500 - loss: 3.3911 - val_accuracy: 0.3000 - val_loss: 1.9958
# Epoch 185/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.1250 - loss: 4.5206 - val_accuracy: 0.3500 - val_loss: 1.7895
# Epoch 186/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3500 - loss: 3.7890 - val_accuracy: 0.3500 - val_loss: 1.6388
# Epoch 187/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2500 - loss: 4.1923 - val_accuracy: 0.3000 - val_loss: 2.1902
# Epoch 188/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3250 - loss: 2.8379 - val_accuracy: 0.3500 - val_loss: 2.0323
# Epoch 189/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.2500 - loss: 3.8417 - val_accuracy: 0.2500 - val_loss: 1.8920
# Epoch 190/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.2500 - loss: 3.9708 - val_accuracy: 0.2500 - val_loss: 2.3985
# Epoch 191/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3000 - loss: 2.7586 - val_accuracy: 0.2500 - val_loss: 2.2794
# Epoch 192/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2750 - loss: 3.6456 - val_accuracy: 0.3000 - val_loss: 1.9838
# Epoch 193/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3500 - loss: 3.8409 - val_accuracy: 0.3000 - val_loss: 2.3064
# Epoch 194/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2500 - loss: 3.3702 - val_accuracy: 0.3000 - val_loss: 1.9201
# Epoch 195/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.2250 - loss: 3.6042 - val_accuracy: 0.4000 - val_loss: 1.8544
# Epoch 196/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2750 - loss: 3.6207 - val_accuracy: 0.3500 - val_loss: 2.0600
# Epoch 197/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2750 - loss: 3.8494 - val_accuracy: 0.3000 - val_loss: 2.0112
# Epoch 198/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3000 - loss: 3.1128 - val_accuracy: 0.3000 - val_loss: 1.9596
# Epoch 199/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4250 - loss: 3.0858 - val_accuracy: 0.3500 - val_loss: 1.9222
# Epoch 200/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2250 - loss: 3.0590 - val_accuracy: 0.3500 - val_loss: 1.6786
# Epoch 201/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.2500 - loss: 3.7455 - val_accuracy: 0.3500 - val_loss: 1.6555
# Epoch 202/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2000 - loss: 3.1175 - val_accuracy: 0.4000 - val_loss: 1.6683
# Epoch 203/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3000 - loss: 2.7981 - val_accuracy: 0.4000 - val_loss: 1.7395
# Epoch 204/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3750 - loss: 3.3599 - val_accuracy: 0.4000 - val_loss: 1.7713
# Epoch 205/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2750 - loss: 2.9660 - val_accuracy: 0.3000 - val_loss: 1.8413
# Epoch 206/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2000 - loss: 4.1940 - val_accuracy: 0.2000 - val_loss: 1.9903
# Epoch 207/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2750 - loss: 3.4672 - val_accuracy: 0.3000 - val_loss: 1.8765
# Epoch 208/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3250 - loss: 3.0176 - val_accuracy: 0.2500 - val_loss: 2.3066
# Epoch 209/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.3000 - loss: 3.5006 - val_accuracy: 0.3000 - val_loss: 1.6936
# Epoch 210/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2750 - loss: 3.3257 - val_accuracy: 0.2500 - val_loss: 1.8027
# Epoch 211/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2500 - loss: 2.4375 - val_accuracy: 0.3000 - val_loss: 2.0833
# Epoch 212/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3500 - loss: 2.8653 - val_accuracy: 0.3000 - val_loss: 1.8492
# Epoch 213/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3500 - loss: 3.1067 - val_accuracy: 0.4500 - val_loss: 1.5638
# Epoch 214/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3250 - loss: 3.2777 - val_accuracy: 0.4000 - val_loss: 1.7343
# Epoch 215/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2000 - loss: 3.7412 - val_accuracy: 0.1000 - val_loss: 1.9251
# Epoch 216/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3000 - loss: 3.3097 - val_accuracy: 0.3000 - val_loss: 1.7013
# Epoch 217/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2750 - loss: 3.5448 - val_accuracy: 0.2000 - val_loss: 1.9157
# Epoch 218/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2250 - loss: 3.0479 - val_accuracy: 0.1500 - val_loss: 2.1541
# Epoch 219/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2750 - loss: 2.6312 - val_accuracy: 0.2000 - val_loss: 2.2934
# Epoch 220/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3500 - loss: 2.8717 - val_accuracy: 0.1500 - val_loss: 2.7412
# Epoch 221/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3750 - loss: 2.4839 - val_accuracy: 0.0500 - val_loss: 3.3676
# Epoch 222/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3750 - loss: 3.5888 - val_accuracy: 0.2000 - val_loss: 1.9706
# Epoch 223/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3500 - loss: 2.9023 - val_accuracy: 0.3500 - val_loss: 1.6286
# Epoch 224/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2500 - loss: 3.5623 - val_accuracy: 0.3500 - val_loss: 1.8221
# Epoch 225/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3000 - loss: 2.7853 - val_accuracy: 0.2500 - val_loss: 1.9835
# Epoch 226/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.2750 - loss: 3.1307 - val_accuracy: 0.3000 - val_loss: 1.8195
# Epoch 227/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2750 - loss: 3.4163 - val_accuracy: 0.1000 - val_loss: 2.4578
# Epoch 228/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3000 - loss: 3.2640 - val_accuracy: 0.1500 - val_loss: 2.1807
# Epoch 229/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2500 - loss: 3.2467 - val_accuracy: 0.2000 - val_loss: 2.1273
# Epoch 230/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2750 - loss: 3.0836 - val_accuracy: 0.3000 - val_loss: 1.8796
# Epoch 231/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.3250 - loss: 2.2200 - val_accuracy: 0.4000 - val_loss: 1.7531
# Epoch 232/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4500 - loss: 2.7453 - val_accuracy: 0.3500 - val_loss: 1.8720
# Epoch 233/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2000 - loss: 2.9365 - val_accuracy: 0.2500 - val_loss: 2.2499
# Epoch 234/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.2500 - loss: 3.3252 - val_accuracy: 0.3500 - val_loss: 1.8301
# Epoch 235/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2500 - loss: 3.1149 - val_accuracy: 0.3000 - val_loss: 2.0445
# Epoch 236/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3250 - loss: 3.3605 - val_accuracy: 0.3500 - val_loss: 1.6719
# Epoch 237/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3000 - loss: 3.3177 - val_accuracy: 0.2000 - val_loss: 1.8116
# Epoch 238/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2250 - loss: 3.1617 - val_accuracy: 0.2500 - val_loss: 1.9697
# Epoch 239/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3000 - loss: 2.7497 - val_accuracy: 0.1500 - val_loss: 2.4044
# Epoch 240/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2750 - loss: 3.1304 - val_accuracy: 0.4000 - val_loss: 1.9299
# Epoch 241/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2500 - loss: 2.6581 - val_accuracy: 0.2500 - val_loss: 1.9594
# Epoch 242/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3750 - loss: 2.5844 - val_accuracy: 0.1500 - val_loss: 2.0421
# Epoch 243/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4250 - loss: 2.2712 - val_accuracy: 0.3500 - val_loss: 1.7061
# Epoch 244/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2750 - loss: 2.9915 - val_accuracy: 0.1500 - val_loss: 1.7528
# Epoch 245/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3500 - loss: 2.3698 - val_accuracy: 0.3000 - val_loss: 1.6470
# Epoch 246/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2750 - loss: 2.9029 - val_accuracy: 0.3500 - val_loss: 1.6531
# Epoch 247/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3500 - loss: 2.3964 - val_accuracy: 0.2000 - val_loss: 1.7502
# Epoch 248/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2750 - loss: 2.8835 - val_accuracy: 0.1500 - val_loss: 2.1132
# Epoch 249/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3500 - loss: 2.9101 - val_accuracy: 0.4000 - val_loss: 1.5239
# Epoch 250/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2250 - loss: 2.4462 - val_accuracy: 0.2000 - val_loss: 1.9293
# Epoch 251/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3500 - loss: 2.8876 - val_accuracy: 0.4500 - val_loss: 1.8997
# Epoch 252/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3250 - loss: 2.6025 - val_accuracy: 0.3500 - val_loss: 1.6623
# Epoch 253/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4000 - loss: 2.6569 - val_accuracy: 0.3500 - val_loss: 1.6917
# Epoch 254/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3000 - loss: 2.5469 - val_accuracy: 0.4500 - val_loss: 1.4722
# Epoch 255/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3000 - loss: 3.3524 - val_accuracy: 0.4500 - val_loss: 1.6841
# Epoch 256/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3750 - loss: 2.6453 - val_accuracy: 0.1500 - val_loss: 1.8690
# Epoch 257/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3250 - loss: 2.6112 - val_accuracy: 0.2000 - val_loss: 1.8982
# Epoch 258/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4250 - loss: 1.9398 - val_accuracy: 0.2500 - val_loss: 1.7139
# Epoch 259/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3000 - loss: 3.0784 - val_accuracy: 0.3500 - val_loss: 1.7101
# Epoch 260/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2750 - loss: 2.7785 - val_accuracy: 0.2000 - val_loss: 2.0903
# Epoch 261/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2500 - loss: 2.7215 - val_accuracy: 0.3500 - val_loss: 1.5292
# Epoch 262/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4250 - loss: 1.7910 - val_accuracy: 0.1500 - val_loss: 1.8481
# Epoch 263/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.3750 - loss: 2.3686 - val_accuracy: 0.3000 - val_loss: 1.6069
# Epoch 264/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2750 - loss: 2.4286 - val_accuracy: 0.1500 - val_loss: 2.0571
# Epoch 265/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2750 - loss: 2.8925 - val_accuracy: 0.2500 - val_loss: 1.8910
# Epoch 266/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3000 - loss: 2.5820 - val_accuracy: 0.3500 - val_loss: 1.6469
# Epoch 267/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3750 - loss: 2.9732 - val_accuracy: 0.4500 - val_loss: 1.7058
# Epoch 268/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2750 - loss: 2.6935 - val_accuracy: 0.5500 - val_loss: 1.4322
# Epoch 269/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3000 - loss: 2.6067 - val_accuracy: 0.4500 - val_loss: 1.4643
# Epoch 270/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3000 - loss: 2.6750 - val_accuracy: 0.2000 - val_loss: 1.8991
# Epoch 271/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3500 - loss: 2.4553 - val_accuracy: 0.4000 - val_loss: 1.6983
# Epoch 272/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4000 - loss: 2.6430 - val_accuracy: 0.1500 - val_loss: 1.7600
# Epoch 273/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2500 - loss: 3.0325 - val_accuracy: 0.3500 - val_loss: 1.7885
# Epoch 274/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3500 - loss: 2.7861 - val_accuracy: 0.3500 - val_loss: 1.7911
# Epoch 275/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3250 - loss: 2.5529 - val_accuracy: 0.3500 - val_loss: 1.6280
# Epoch 276/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1500 - loss: 3.0097 - val_accuracy: 0.4000 - val_loss: 1.5420
# Epoch 277/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2000 - loss: 2.4629 - val_accuracy: 0.2500 - val_loss: 1.7975
# Epoch 278/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2750 - loss: 2.5008 - val_accuracy: 0.3500 - val_loss: 1.5031
# Epoch 279/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3000 - loss: 2.7040 - val_accuracy: 0.2000 - val_loss: 1.8933
# Epoch 280/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4000 - loss: 2.5664 - val_accuracy: 0.1500 - val_loss: 1.8647
# Epoch 281/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3750 - loss: 2.0735 - val_accuracy: 0.3500 - val_loss: 1.5108
# Epoch 282/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4500 - loss: 2.1428 - val_accuracy: 0.5000 - val_loss: 1.4458
# Epoch 283/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3250 - loss: 2.8168 - val_accuracy: 0.2000 - val_loss: 1.8752
# Epoch 284/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4750 - loss: 2.0083 - val_accuracy: 0.3000 - val_loss: 1.7403
# Epoch 285/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3750 - loss: 2.5830 - val_accuracy: 0.2500 - val_loss: 1.8886
# Epoch 286/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3000 - loss: 2.4029 - val_accuracy: 0.4000 - val_loss: 1.6569
# Epoch 287/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4000 - loss: 2.1395 - val_accuracy: 0.4500 - val_loss: 1.5742
# Epoch 288/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4000 - loss: 2.6116 - val_accuracy: 0.3500 - val_loss: 1.6593
# Epoch 289/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3750 - loss: 2.2514 - val_accuracy: 0.3000 - val_loss: 1.6515
# Epoch 290/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4250 - loss: 1.8573 - val_accuracy: 0.2000 - val_loss: 1.6996
# Epoch 291/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2500 - loss: 2.1956 - val_accuracy: 0.3000 - val_loss: 1.5339
# Epoch 292/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.3750 - loss: 2.0139 - val_accuracy: 0.3000 - val_loss: 1.7748
# Epoch 293/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3500 - loss: 2.8418 - val_accuracy: 0.2500 - val_loss: 1.7346
# Epoch 294/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.4250 - loss: 2.2017 - val_accuracy: 0.2500 - val_loss: 1.6932
# Epoch 295/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4250 - loss: 2.1625 - val_accuracy: 0.2000 - val_loss: 2.1617
# Epoch 296/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3250 - loss: 2.6189 - val_accuracy: 0.4000 - val_loss: 1.7447
# Epoch 297/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.3250 - loss: 2.6447 - val_accuracy: 0.3500 - val_loss: 1.7307
# Epoch 298/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.3250 - loss: 2.8187 - val_accuracy: 0.4000 - val_loss: 1.5601
# Epoch 299/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2750 - loss: 2.8616 - val_accuracy: 0.2000 - val_loss: 1.8648
# Epoch 300/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4000 - loss: 1.8153 - val_accuracy: 0.3500 - val_loss: 1.8497
# Epoch 301/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.3750 - loss: 2.5729 - val_accuracy: 0.4500 - val_loss: 1.6939
# Epoch 302/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.2250 - loss: 2.4790 - val_accuracy: 0.2000 - val_loss: 1.9331
# Epoch 303/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4000 - loss: 2.0151 - val_accuracy: 0.3000 - val_loss: 1.8188
# Epoch 304/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3500 - loss: 2.0433 - val_accuracy: 0.4500 - val_loss: 1.5782
# Epoch 305/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3000 - loss: 2.6805 - val_accuracy: 0.1500 - val_loss: 2.1322
# Epoch 306/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4750 - loss: 1.8528 - val_accuracy: 0.1500 - val_loss: 2.1134
# Epoch 307/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3000 - loss: 1.9304 - val_accuracy: 0.3000 - val_loss: 1.7251
# Epoch 308/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3250 - loss: 2.5055 - val_accuracy: 0.2000 - val_loss: 1.9498
# Epoch 309/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4750 - loss: 1.8792 - val_accuracy: 0.3000 - val_loss: 1.6492
# Epoch 310/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3500 - loss: 2.2704 - val_accuracy: 0.2500 - val_loss: 1.8669
# Epoch 311/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3000 - loss: 2.4026 - val_accuracy: 0.2500 - val_loss: 1.9495
# Epoch 312/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3500 - loss: 2.3397 - val_accuracy: 0.4000 - val_loss: 1.5785
# Epoch 313/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3750 - loss: 1.9009 - val_accuracy: 0.3500 - val_loss: 1.5225
# Epoch 314/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0
1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3500 - loss: 1.9080 - val_accuracy: 0.5000 - val_loss: 1.5112
# Epoch 348/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5000 - loss: 1.7428 - val_accuracy: 0.3000 - val_loss: 1.7186
# Epoch 349/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3500 - loss: 1.9649 - val_accuracy: 0.3500 - val_loss: 1.5245
# Epoch 350/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5500 - loss: 1.5518 - val_accuracy: 0.4500 - val_loss: 1.4770
# Epoch 351/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4500 - loss: 1.9186 - val_accuracy: 0.3000 - val_loss: 1.6818
# Epoch 352/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3750 - loss: 1.8979 - val_accuracy: 0.2500 - val_loss: 1.6848
# Epoch 353/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3000 - loss: 2.1694 - val_accuracy: 0.4500 - val_loss: 1.5148
# Epoch 354/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3750 - loss: 1.7198 - val_accuracy: 0.5000 - val_loss: 1.3673
# Epoch 355/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4500 - loss: 1.5876 - val_accuracy: 0.5500 - val_loss: 1.3819
# Epoch 356/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6750 - loss: 1.3139 - val_accuracy: 0.5000 - val_loss: 1.5198
# Epoch 357/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3750 - loss: 1.9269 - val_accuracy: 0.3000 - val_loss: 1.8520
# Epoch 358/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3750 - loss: 1.8125 - val_accuracy: 0.5000 - val_loss: 1.3196
# Epoch 359/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3500 - loss: 1.9563 - val_accuracy: 0.5000 - val_loss: 1.2902
# Epoch 360/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5000 - loss: 1.5790 - val_accuracy: 0.5000 - val_loss: 1.3670
# Epoch 361/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3750 - loss: 2.2389 - val_accuracy: 0.4000 - val_loss: 1.5369
# Epoch 362/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.3750 - loss: 1.6559 - val_accuracy: 0.4000 - val_loss: 1.5587
# Epoch 363/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3750 - loss: 2.1288 - val_accuracy: 0.3500 - val_loss: 1.5572
# Epoch 364/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3500 - loss: 1.8286 - val_accuracy: 0.2000 - val_loss: 1.8845
# Epoch 365/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4250 - loss: 2.1801 - val_accuracy: 0.5500 - val_loss: 1.4696
# Epoch 366/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4000 - loss: 1.8565 - val_accuracy: 0.5500 - val_loss: 1.4482
# Epoch 367/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4250 - loss: 1.4791 - val_accuracy: 0.5500 - val_loss: 1.3193
# Epoch 368/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3750 - loss: 1.6437 - val_accuracy: 0.4500 - val_loss: 1.3764
# Epoch 369/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5250 - loss: 1.6807 - val_accuracy: 0.5500 - val_loss: 1.3745
# Epoch 370/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4250 - loss: 1.5701 - val_accuracy: 0.4500 - val_loss: 1.4861
# Epoch 371/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3750 - loss: 1.6871 - val_accuracy: 0.5000 - val_loss: 1.5424
# Epoch 372/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2500 - loss: 2.4317 - val_accuracy: 0.4500 - val_loss: 1.3813
# Epoch 373/1000
# ...
# Epoch 877/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7500 - loss: 0.8113 - val_accuracy: 0.6500 - val_loss: 0.9022
# Epoch 878/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7000 - loss: 0.7741 - val_accuracy: 0.6500 - val_loss: 0.9303
# Epoch 879/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8000 - loss: 0.8245 - val_accuracy: 0.7000 - val_loss: 0.9079
# Epoch 880/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6500 - loss: 1.1693 - val_accuracy: 0.6000 - val_loss: 0.9948
# Epoch 881/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.8334 - val_accuracy: 0.6500 - val_loss: 0.9030
# Epoch 882/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7500 - loss: 0.8374 - val_accuracy: 0.6000 - val_loss: 0.8698
# Epoch 883/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8000 - loss: 0.7016 - val_accuracy: 0.6500 - val_loss: 0.8787
# Epoch 884/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7250 - loss: 0.6475 - val_accuracy: 0.6000 - val_loss: 0.9347
# Epoch 885/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7000 - loss: 0.7774 - val_accuracy: 0.6500 - val_loss: 1.0838
# Epoch 886/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6500 - loss: 0.8056 - val_accuracy: 0.6500 - val_loss: 0.9275
# Epoch 887/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8000 - loss: 0.6314 - val_accuracy: 0.6000 - val_loss: 1.1173
# Epoch 888/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7000 - loss: 0.8279 - val_accuracy: 0.6500 - val_loss: 0.8682
# Epoch 889/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8000 - loss: 0.6924 - val_accuracy: 0.6000 - val_loss: 1.0105
# Epoch 890/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8250 - loss: 0.5937 - val_accuracy: 0.5000 - val_loss: 1.0759
# Epoch 891/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8250 - loss: 0.6530 - val_accuracy: 0.6500 - val_loss: 0.9132
# Epoch 892/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7750 - loss: 0.8091 - val_accuracy: 0.5500 - val_loss: 1.1112
# Epoch 893/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7000 - loss: 0.6941 - val_accuracy: 0.7000 - val_loss: 0.8901
# Epoch 894/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7750 - loss: 0.7490 - val_accuracy: 0.5500 - val_loss: 1.0740
# Epoch 895/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.8017 - val_accuracy: 0.6500 - val_loss: 0.9143
# Epoch 896/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6500 - loss: 0.9412 - val_accuracy: 0.5500 - val_loss: 0.9449
# Epoch 897/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7250 - loss: 0.8595 - val_accuracy: 0.6000 - val_loss: 1.0292
# Epoch 898/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7000 - loss: 0.7984 - val_accuracy: 0.6000 - val_loss: 0.9561
# Epoch 899/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7500 - loss: 0.7605 - val_accuracy: 0.6500 - val_loss: 0.9184
# Epoch 900/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8000 - loss: 0.7223 - val_accuracy: 0.5500 - val_loss: 0.9892
# Epoch 901/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8250 - loss: 0.6424 - val_accuracy: 0.6500 - val_loss: 0.8761
# Epoch 902/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7500 - loss: 0.7749 - val_accuracy: 0.7000 - val_loss: 0.8844
# Epoch 903/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6750 - loss: 0.7948 - val_accuracy: 0.7000 - val_loss: 0.8076
# Epoch 904/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8500 - loss: 0.6062 - val_accuracy: 0.5500 - val_loss: 0.9935
# Epoch 905/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7500 - loss: 0.7099 - val_accuracy: 0.6500 - val_loss: 0.9984
# Epoch 906/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8500 - loss: 0.7161 - val_accuracy: 0.6500 - val_loss: 1.0302
# Epoch 907/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6750 - loss: 0.8463 - val_accuracy: 0.6500 - val_loss: 1.0053
# Epoch 908/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8000 - loss: 0.6263 - val_accuracy: 0.6000 - val_loss: 0.8741
# Epoch 909/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7500 - loss: 0.7388 - val_accuracy: 0.6500 - val_loss: 0.8815
# Epoch 910/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6000 - loss: 0.9861 - val_accuracy: 0.7500 - val_loss: 0.8649
# Epoch 911/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7250 - loss: 0.7216 - val_accuracy: 0.6500 - val_loss: 0.8592
# Epoch 912/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6750 - loss: 0.7177 - val_accuracy: 0.6000 - val_loss: 0.9072
# Epoch 913/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8500 - loss: 0.6149 - val_accuracy: 0.6500 - val_loss: 0.9567
# Epoch 914/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8000 - loss: 0.5706 - val_accuracy: 0.6000 - val_loss: 1.0139
# Epoch 915/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7250 - loss: 0.8566 - val_accuracy: 0.5500 - val_loss: 0.9235
# Epoch 916/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.
1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7750 - loss: 0.7805 - val_accuracy: 0.7000 - val_loss: 0.8170
# Epoch 982/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8000 - loss: 0.6699 - val_accuracy: 0.6000 - val_loss: 0.9186
# Epoch 983/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7750 - loss: 0.6405 - val_accuracy: 0.6000 - val_loss: 0.9878
# Epoch 984/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9250 - loss: 0.4923 - val_accuracy: 0.5500 - val_loss: 1.0028
# Epoch 985/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7500 - loss: 0.7506 - val_accuracy: 0.6500 - val_loss: 0.8970
# Epoch 986/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7750 - loss: 0.6440 - val_accuracy: 0.6500 - val_loss: 0.8498
# Epoch 987/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7500 - loss: 0.6416 - val_accuracy: 0.7000 - val_loss: 0.8001
# Epoch 988/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7500 - loss: 0.7388 - val_accuracy: 0.6500 - val_loss: 0.8381
# Epoch 989/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7250 - loss: 0.6703 - val_accuracy: 0.6000 - val_loss: 0.8843
# Epoch 990/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8000 - loss: 0.7298 - val_accuracy: 0.7000 - val_loss: 0.8462
# Epoch 991/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8500 - loss: 0.6411 - val_accuracy: 0.7500 - val_loss: 0.9178
# Epoch 992/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7750 - loss: 0.7070 - val_accuracy: 0.6000 - val_loss: 0.9557
# Epoch 993/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8000 - loss: 0.6369 - val_accuracy: 0.5500 - val_loss: 0.9455
# Epoch 994/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8250 - loss: 0.6419 - val_accuracy: 0.6000 - val_loss: 0.9570
# Epoch 995/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8750 - loss: 0.4802 - val_accuracy: 0.5500 - val_loss: 0.8727
# Epoch 996/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8000 - loss: 0.6137 - val_accuracy: 0.7000 - val_loss: 0.8397
# Epoch 997/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7500 - loss: 0.6770 - val_accuracy: 0.7000 - val_loss: 0.9133
# Epoch 998/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8250 - loss: 0.5039 - val_accuracy: 0.6000 - val_loss: 0.9253
# Epoch 999/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8250 - loss: 0.5571 - val_accuracy: 0.6500 - val_loss: 0.8650
# Epoch 1000/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8250 - loss: 0.5559 - val_accuracy: 0.6500 - val_loss: 0.8533

# %% [markdown]
# Let's plot the loss:

# %%
plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# And now let's plot the accuracy:

# %%
print(cnnhistory.history.keys())
plt.plot(cnnhistory.history['accuracy'])
plt.plot(cnnhistory.history['val_accuracy'])
plt.title('model accuracy')                                                                                                                                                                   
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %% [markdown]
# # Save the model

# %%
model_name = 'Emotion_Voice_Detection_Model.h5'
save_dir = '/content/drive/My Drive/Ravdess_model'
# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved trained model at /content/drive/My Drive/Ravdess_model\Emotion_Voice_Detection_Model.h5

# %% [markdown]
# # Reloading the model to test it

# %%
loaded_model = keras.models.load_model('/content/drive/My Drive/Ravdess_model/Emotion_Voice_Detection_Model.h5')
loaded_model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_12 (Conv1D)              │ (None, 40, 128)        │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 40, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 40, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_13 (Conv1D)              │ (None, 5, 128)         │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_19 (Activation)      │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 5, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 640)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 10)             │         6,410 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_20 (Activation)      │ (None, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 89,228 (348.55 KB)
#  Trainable params: 89,226 (348.54 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# # Checking the accuracy of the loaded model

# %%
loss, acc = loaded_model.evaluate(x_testcnn, y_test)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.6500 - loss: 0.8533
# Restored model, accuracy: 65.00%

# %% [markdown]
# # Thank you for your attention! To be continued..
